# %%
import geopandas as gpd
import pandas as pd
import re
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %%
geo_df = gpd.read_file('Neighborhood_Map_Atlas_Neighborhoods.geojson')
geo_df.head()
# Out:
#    OBJECTID         L_HOOD            S_HOOD S_HOOD_ALT_NAMES   Shape__Area  \
# 0        27        Ballard     Loyal Heights             None  2.132066e+07
# 1        28        Ballard           Ballard            Adams  2.255213e+07
# 2        29        Ballard  Whittier Heights             None  1.419569e+07
# 3        30        Ballard     West Woodland             None  2.219937e+07
# 4        31  North Central     Phinney Ridge    Woodland Park  3.212312e+07
#
#    Shape__Length                                           geometry
# 0   18831.009596  POLYGON ((-122.37634 47.67592, -122.37671 47.6...
# 1   29926.339300  POLYGON ((-122.37622 47.66818, -122.37621 47.6...
# 2   15934.439266  POLYGON ((-122.37634 47.67592, -122.37652 47.6...
# 3   21789.651087  POLYGON ((-122.37634 47.67592, -122.37608 47.6...
# 4   27120.785938  POLYGON ((-122.34731 47.66501, -122.34887 47.6...

# %%
df1 = pd.read_csv('listings1.csv')
df2 = pd.read_csv('listings2.csv')
df3 = pd.read_csv('listings3.csv')
df4 = pd.read_csv('listings4.csv')
df = pd.concat([df1, df2, df3,df4], ignore_index=True)
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  6606  https://www.airbnb.com/rooms/6606  20230324234225   2023-03-25
# 1  9419  https://www.airbnb.com/rooms/9419  20230324234225   2023-03-25
# 2  9531  https://www.airbnb.com/rooms/9531  20230324234225   2023-03-25
# 3  9534  https://www.airbnb.com/rooms/9534  20230324234225   2023-03-25
# 4  9596  https://www.airbnb.com/rooms/9596  20230324234225   2023-03-25
#
#             source                                        name  \
# 0      city scrape         Fab, private seattle urban cottage!
# 1      city scrape         Glorious sun room w/ memory foambed
# 2      city scrape         The Adorable Sweet Orange Craftsman
# 3      city scrape            The Coolest Tangerine Dream MIL!
# 4  previous scrape  the down home , spacious, central and fab!
#
#                                          description  \
# 0  This tiny cottage is only 15x10, but it has ev...
# 1  Keeping you safe is our priority, we are adher...
# 2  The Sweet Orange is a delightful and spacious ...
# 3  Welcome to my delicious Tangerine Dream!  A co...
# 4  We are in a great neighborhood, quiet, full of...
#
#                                neighborhood_overview  \
# 0  A peaceful yet highly accessible neighborhood,...
# 1  Lots of restaurants (see our guide book) bars,...
# 2  The neighborhood is awesome!  Just far enough ...
# 3  The neighborhood is the best of two worlds...w...
# 4  if you arrive early for check in at 3,  I reco...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/45742/21116d7...    14942
# 1  https://a0.muscache.com/pictures/56645186/e5fb...    30559
# 2  https://a0.muscache.com/pictures/30470355/052c...    31481
# 3  https://a0.muscache.com/pictures/30476721/0751...    31481
# 4  https://a0.muscache.com/pictures/665252/102d18...    14942
#
#                                   host_url  host_name  host_since  \
# 0  https://www.airbnb.com/users/show/14942      Joyce  2009-04-26
# 1  https://www.airbnb.com/users/show/30559  Angielena  2009-08-09
# 2  https://www.airbnb.com/users/show/31481     Cassie  2009-08-13
# 3  https://www.airbnb.com/users/show/31481     Cassie  2009-08-13
# 4  https://www.airbnb.com/users/show/14942      Joyce  2009-04-26
#
#   host_location                                         host_about  \
# 0   Seattle, WA  I am a therapist/innkeeper.I know my city well...
# 1   Seattle, WA     I am a visual artist who is  the  director ...
# 2   Seattle, WA  The Sweet Orange reflects my passion and zest ...
# 3   Seattle, WA  The Sweet Orange reflects my passion and zest ...
# 4   Seattle, WA  I am a therapist/innkeeper.I know my city well...
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  within a few hours               100%                  94%
# 1      within an hour               100%                  98%
# 2  within a few hours               100%                  77%
# 3  within a few hours               100%                  77%
# 4  within a few hours               100%                  94%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/users/14942/profile...
# 1                 t  https://a0.muscache.com/im/users/30559/profile...
# 2                 t  https://a0.muscache.com/im/users/31481/profile...
# 3                 t  https://a0.muscache.com/im/users/31481/profile...
# 4                 f  https://a0.muscache.com/im/users/14942/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/14942/profile...        Wallingford
# 1  https://a0.muscache.com/im/users/30559/profile...         Georgetown
# 2  https://a0.muscache.com/im/users/31481/profile...       The Junction
# 3  https://a0.muscache.com/im/users/31481/profile...       The Junction
# 4  https://a0.muscache.com/im/users/14942/profile...        Wallingford
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                    5                          5  ['email', 'phone']
# 1                    9                         10  ['email', 'phone']
# 2                    2                          2  ['email', 'phone']
# 3                    2                          2  ['email', 'phone']
# 4                    5                          5  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      t
# 3                    t                      t
# 4                    t                      t
#
#                         neighbourhood neighbourhood_cleansed  \
# 0  Seattle, Washington, United States            Wallingford
# 1  Seattle, Washington, United States             Georgetown
# 2  Seattle, Washington, United States         Fairmount Park
# 3  Seattle, Washington, United States         Fairmount Park
# 4  Seattle, Washington, United States            Wallingford
#
#   neighbourhood_group_cleansed  latitude  longitude  \
# 0          Other neighborhoods  47.65444 -122.33629
# 1          Other neighborhoods  47.55017 -122.31937
# 2                 West Seattle  47.55495 -122.38663
# 3                 West Seattle  47.55627 -122.38607
# 4          Other neighborhoods  47.65608 -122.33602
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0            Entire guesthouse  Entire home/apt             1        NaN
# 1  Private room in rental unit     Private room             2        NaN
# 2                  Entire home  Entire home/apt             4        NaN
# 3           Entire guest suite  Entire home/apt             3        NaN
# 4           Entire rental unit  Entire home/apt             4        NaN
#
#    bathrooms_text  bedrooms  beds  \
# 0          1 bath       1.0   1.0
# 1  3 shared baths       1.0   2.0
# 2          1 bath       2.0   3.0
# 3          1 bath       2.0   2.0
# 4          1 bath       1.0   4.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Air conditioning", "Hair dryer", "Bed linens...   $99.00              30
# 1  ["Long term stays allowed", "Shared patio or b...   $55.00               2
# 2  ["Long term stays allowed", "Conditioner", "Cl...  $175.00               3
# 3  ["Long term stays allowed", "Conditioner", "Cl...  $135.00               2
# 4  ["Stove", "Hair dryer", "Shampoo", "Coffee mak...  $130.00              30
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                    30.0                    30.0
# 1              90                     2.0                     2.0
# 2            1125                     2.0                    30.0
# 3            1125                     2.0                     2.0
# 4             200                    30.0                    30.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                  1125.0                  1125.0                    30.0
# 1                    90.0                    90.0                     2.0
# 2                     2.0                  1125.0                     7.5
# 3                  1125.0                  1125.0                     2.0
# 4                   200.0                   200.0                    30.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t               22
# 1                    90.0               NaN                t               28
# 2                  1023.3               NaN                t                0
# 3                  1125.0               NaN                t                0
# 4                   200.0               NaN                t               22
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               28               50                99            2023-03-25
# 1               58               85               356            2023-03-25
# 2               13               20               228            2023-03-25
# 3                0               24               231            2023-03-25
# 4               45               65                65            2023-03-25
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                159                      2                       0
# 1                175                     20                       0
# 2                 71                     11                       0
# 3                 73                     13                       1
# 4                 97                      0                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2009-07-17  2022-09-03                  4.61                    4.67
# 1   2010-07-30  2023-01-15                  4.70                    4.78
# 2   2012-01-12  2022-12-28                  4.96                    4.99
# 3   2012-01-15  2023-03-09                  4.99                    4.99
# 4   2011-06-15  2020-09-28                  4.56                    4.55
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.67                   4.83
# 1                       4.73                   4.93
# 2                       4.97                   4.99
# 3                       4.99                   5.00
# 4                       4.50                   4.80
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.76                    4.88                 4.57
# 1                         4.88                    4.65                 4.65
# 2                         4.96                    4.97                 4.90
# 3                         4.99                    4.96                 4.94
# 4                         4.66                    4.91                 4.56
#
#                license instant_bookable  calculated_host_listings_count  \
# 0   str-opli-19-002622                f                               3
# 1   STR-OPLI-19-003039                f                               9
# 2   STR-OPLI-19-002182                f                               2
# 3   STR-OPLI-19-002182                f                               2
# 4  STR -OPLI-19-002622                f                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            3
# 1                                            0
# 2                                            2
# 3                                            2
# 4                                            3
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             9
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.95
# 1                                            0               1.14
# 2                                            0               0.52
# 3                                            0               0.54
# 4                                            0               0.68

# %%
selected_columns = ['id', 'name', 'neighbourhood_cleansed','latitude','longitude','property_type','room_type','accommodates',
                   'bathrooms_text','bedrooms','beds','price','availability_90','number_of_reviews','review_scores_rating',
                    'review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication',
                   'review_scores_location','review_scores_value'] 
df = df[selected_columns]
df.head()
# Out:
#      id                                        name neighbourhood_cleansed  \
# 0  6606         Fab, private seattle urban cottage!            Wallingford
# 1  9419         Glorious sun room w/ memory foambed             Georgetown
# 2  9531         The Adorable Sweet Orange Craftsman         Fairmount Park
# 3  9534            The Coolest Tangerine Dream MIL!         Fairmount Park
# 4  9596  the down home , spacious, central and fab!            Wallingford
#
#    latitude  longitude                property_type        room_type  \
# 0  47.65444 -122.33629            Entire guesthouse  Entire home/apt
# 1  47.55017 -122.31937  Private room in rental unit     Private room
# 2  47.55495 -122.38663                  Entire home  Entire home/apt
# 3  47.55627 -122.38607           Entire guest suite  Entire home/apt
# 4  47.65608 -122.33602           Entire rental unit  Entire home/apt
#
#    accommodates  bathrooms_text  bedrooms  beds    price  availability_90  \
# 0             1          1 bath       1.0   1.0   $99.00               50
# 1             2  3 shared baths       1.0   2.0   $55.00               85
# 2             4          1 bath       2.0   3.0  $175.00               20
# 3             3          1 bath       2.0   2.0  $135.00               24
# 4             4          1 bath       1.0   4.0  $130.00               65
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                159                  4.61                    4.67
# 1                175                  4.70                    4.78
# 2                 71                  4.96                    4.99
# 3                 73                  4.99                    4.99
# 4                 97                  4.56                    4.55
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.67                   4.83
# 1                       4.73                   4.93
# 2                       4.97                   4.99
# 3                       4.99                   5.00
# 4                       4.50                   4.80
#
#    review_scores_communication  review_scores_location  review_scores_value
# 0                         4.76                    4.88                 4.57
# 1                         4.88                    4.65                 4.65
# 2                         4.96                    4.97                 4.90
# 3                         4.99                    4.96                 4.94
# 4                         4.66                    4.91                 4.56

# %%
df_availability = (df.groupby('id')['availability_90'].sum().reset_index(name='availability in one year'))
unique_listing_info = df.drop_duplicates('id').drop('availability_90', axis=1)
df = pd.merge(df_availability, unique_listing_info, on='id')
df.head()
# Out:
#      id  availability in one year                                        name  \
# 0  6606                       273         Fab, private seattle urban cottage!
# 1  9419                       336         Glorious sun room w/ memory foambed
# 2  9531                       176         The Adorable Sweet Orange Craftsman
# 3  9534                        39            The Coolest Tangerine Dream MIL!
# 4  9596                       125  the down home , spacious, central and fab!
#
#   neighbourhood_cleansed  latitude  longitude                property_type  \
# 0            Wallingford  47.65444 -122.33629            Entire guesthouse
# 1             Georgetown  47.55017 -122.31937  Private room in rental unit
# 2         Fairmount Park  47.55495 -122.38663                  Entire home
# 3         Fairmount Park  47.55627 -122.38607           Entire guest suite
# 4            Wallingford  47.65608 -122.33602           Entire rental unit
#
#          room_type  accommodates  bathrooms_text  bedrooms  beds    price  \
# 0  Entire home/apt             1          1 bath       1.0   1.0   $99.00
# 1     Private room             2  3 shared baths       1.0   2.0   $55.00
# 2  Entire home/apt             4          1 bath       2.0   3.0  $175.00
# 3  Entire home/apt             3          1 bath       2.0   2.0  $135.00
# 4  Entire home/apt             4          1 bath       1.0   4.0  $130.00
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                159                  4.61                    4.67
# 1                175                  4.70                    4.78
# 2                 71                  4.96                    4.99
# 3                 73                  4.99                    4.99
# 4                 97                  4.56                    4.55
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.67                   4.83
# 1                       4.73                   4.93
# 2                       4.97                   4.99
# 3                       4.99                   5.00
# 4                       4.50                   4.80
#
#    review_scores_communication  review_scores_location  review_scores_value
# 0                         4.76                    4.88                 4.57
# 1                         4.88                    4.65                 4.65
# 2                         4.96                    4.97                 4.90
# 3                         4.99                    4.96                 4.94
# 4                         4.66                    4.91                 4.56

# %%
bedrooms_pattern = r'(\d+)\s+bedroom'
bed_pattern = r'(\d+)\s+bed'

for index, row in df.iterrows():
    if pd.isna(row['bedrooms']):
        if 'studio' in row['name'].lower():
            df.loc[index, 'bedrooms'] = 0
        else:
            bedrooms_match = re.search(bedrooms_pattern, row['name'])
            if bedrooms_match:
                df.loc[index, 'bedrooms'] = int(bedrooms_match.group(1))

    if pd.isna(row['beds']):
        bed_match = re.search(bed_pattern, row['name'])
        if bed_match:
            df.loc[index, 'beds'] = int(bed_match.group(1))

# %%
unique_bathroom_types = df['bathrooms_text'].unique()
print(unique_bathroom_types)
# Out:
# ['1 bath' '3 shared baths' '2 baths' '1.5 baths' '2.5 baths'
#  '4 shared baths' '1 shared bath' '3 baths' '1 private bath' '4 baths'
#  '1.5 shared baths' '3.5 baths' 'Shared half-bath' '2 shared baths'
#  'Half-bath' '2.5 shared baths' '3.5 shared baths' '0 shared baths'
#  '4.5 baths' 'Private half-bath' '16 shared baths' '0 baths' '6 baths' nan
#  '6.5 baths' '7 baths' '5.5 baths' '5 baths']

# %%
import re

df['bathroom_count'] = df['bathrooms_text'].apply(lambda x: float(re.search(r'(\d+\.?\d*)', x).group(1)) if isinstance(x, str) and re.search(r'(\d+\.?\d*)', x) else 0)

def extract_bathroom_type(text):
    if not isinstance(text, str):
        return 'unknown' 
    if 'shared' in text:
        return 'shared'
    elif 'private' in text:
        return 'private'
    elif 'half-bath' in text:
        return 'half-bath'
    else:
        return 'standard'

df['bathroom_type'] = df['bathrooms_text'].apply(extract_bathroom_type)

# %%
df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
missing_percentage = df.isna().sum() / len(df) * 100
print(missing_percentage)
# Out:
# id                              0.000000
# availability in one year        0.000000
# name                            0.000000
# neighbourhood_cleansed          0.000000
# latitude                        0.000000
# longitude                       0.000000
# property_type                   0.000000
# room_type                       0.000000
# accommodates                    0.000000
# bathrooms_text                  0.011518
# bedrooms                        4.192582
# beds                            1.128772
# price                           0.195807
# number_of_reviews               0.000000
# review_scores_rating           23.946095
# review_scores_accuracy         23.992168
# review_scores_cleanliness      23.992168
# review_scores_checkin          23.992168
# review_scores_communication    23.992168
# review_scores_location         23.992168
# review_scores_value            23.992168
# bathroom_count                  0.000000
# bathroom_type                   0.000000
# dtype: float64

# %%
df = df.dropna(subset=['price','bedrooms','beds'])

# %%
missing_percentage = df.isna().sum() / len(df) * 100
print(missing_percentage)
# Out:
# id                              0.000000
# availability in one year        0.000000
# name                            0.000000
# neighbourhood_cleansed          0.000000
# latitude                        0.000000
# longitude                       0.000000
# property_type                   0.000000
# room_type                       0.000000
# accommodates                    0.000000
# bathrooms_text                  0.000000
# bedrooms                        0.000000
# beds                            0.000000
# price                           0.000000
# number_of_reviews               0.000000
# review_scores_rating           24.312485
# review_scores_accuracy         24.361158
# review_scores_cleanliness      24.361158
# review_scores_checkin          24.361158
# review_scores_communication    24.361158
# review_scores_location         24.361158
# review_scores_value            24.361158
# bathroom_count                  0.000000
# bathroom_type                   0.000000
# dtype: float64

# %%
df.to_csv('processedListingDATA.csv', index=False)
