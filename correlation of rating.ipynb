# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('processedListingDATA(4 seasons).csv')
df.head()
# Out:
#      id  availability in one year                                        name  \
# 0  6606                       273         Fab, private seattle urban cottage!
# 1  9419                       336         Glorious sun room w/ memory foambed
# 2  9531                       176         The Adorable Sweet Orange Craftsman
# 3  9534                        39            The Coolest Tangerine Dream MIL!
# 4  9596                       125  the down home , spacious, central and fab!
#
#   neighbourhood_cleansed  latitude  longitude                property_type  \
# 0            Wallingford  47.65444 -122.33629            Entire guesthouse
# 1             Georgetown  47.55017 -122.31937  Private room in rental unit
# 2         Fairmount Park  47.55495 -122.38663                  Entire home
# 3         Fairmount Park  47.55627 -122.38607           Entire guest suite
# 4            Wallingford  47.65608 -122.33602           Entire rental unit
#
# ...

# %%
selected_columns = ['review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication',
                   'review_scores_location','review_scores_value'] 
df_selected = df[selected_columns]
df_selected.head()
# Out:
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.61                    4.67                       4.67
# 1                  4.70                    4.78                       4.73
# 2                  4.96                    4.99                       4.97
# 3                  4.99                    4.99                       4.99
# 4                  4.56                    4.55                       4.50
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.83                         4.76                    4.88
# 1                   4.93                         4.88                    4.65
# 2                   4.99                         4.96                    4.97
# 3                   5.00                         4.99                    4.96
# 4                   4.80                         4.66                    4.91
#
#    review_scores_value
# ...

# %%
df_selected.describe()
# Out:
#        review_scores_rating  review_scores_accuracy  \
# count           6220.000000             6216.000000
# mean               4.784375                4.826628
# std                0.402947                0.352692
# min                0.000000                1.000000
# 25%                4.750000                4.810000
# 50%                4.900000                4.930000
# 75%                5.000000                5.000000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                6216.000000            6216.000000
# mean                    4.802376               4.864511
# std                     0.365597               0.329797
# min                     1.000000               1.000000
# 25%                     4.760000               4.870000
# 50%                     4.930000               4.970000
# 75%                     5.000000               5.000000
# ...

# %%
NA_count = df_selected.isna().sum()
print(NA_count)
# Out:
# review_scores_rating           1998
# review_scores_accuracy         2002
# review_scores_cleanliness      2002
# review_scores_checkin          2002
# review_scores_communication    2002
# review_scores_location         2002
# review_scores_value            2002
# dtype: int64

# %%
cleaned_df = df_selected.dropna()

# %%
correlation_matrix = cleaned_df.corr()

# %%
correlation_matrix.style.background_gradient(cmap='coolwarm').format("{:.2f}")
# Out:
# <style type="text/css">
# #T_a79df_row0_col0, #T_a79df_row1_col1, #T_a79df_row2_col2, #T_a79df_row3_col3, #T_a79df_row4_col4, #T_a79df_row5_col5, #T_a79df_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a79df_row0_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_a79df_row0_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_a79df_row0_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_a79df_row0_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a79df_row0_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_a79df_row0_col6 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a79df_row1_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_a79df_row1_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_a79df_row1_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a79df_row1_col4, #T_a79df_row6_col4 {
#   background-color: #c0d4f5;
# ...
