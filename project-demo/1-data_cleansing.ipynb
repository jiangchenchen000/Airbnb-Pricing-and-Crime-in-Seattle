# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import re
import numpy as np

# %%
# Dataset used for analysis: the 4th seasonal data of Airbnb listing
df_all = pd.read_csv('./data/listings.csv')

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6882 entries, 0 to 6881
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6882 non-null   int64
#  1   listing_url                                   6882 non-null   object
#  2   scrape_id                                     6882 non-null   int64
#  3   last_scraped                                  6882 non-null   object
#  4   source                                        6882 non-null   object
#  5   name                                          6882 non-null   object
#  6   description                                   0 non-null      float64
#  7   neighborhood_overview                         5013 non-null   object
#  8   picture_url                                   6882 non-null   object
#  9   host_id                                       6882 non-null   int64
#  10  host_url                                      6882 non-null   object
#  11  host_name                                     6882 non-null   object
#  12  host_since                                    6882 non-null   object
#  13  host_location                                 5816 non-null   object
#  14  host_about                                    4747 non-null   object
#  15  host_response_time                            5940 non-null   object
#  16  host_response_rate                            5940 non-null   object
#  17  host_acceptance_rate                          6297 non-null   object
#  18  host_is_superhost                             6864 non-null   object
#  19  host_thumbnail_url                            6882 non-null   object
#  20  host_picture_url                              6882 non-null   object
#  21  host_neighbourhood                            6552 non-null   object
#  22  host_listings_count                           6882 non-null   int64
#  23  host_total_listings_count                     6882 non-null   int64
#  24  host_verifications                            6882 non-null   object
#  25  host_has_profile_pic                          6882 non-null   object
#  26  host_identity_verified                        6882 non-null   object
#  27  neighbourhood                                 5013 non-null   object
#  28  neighbourhood_cleansed                        6882 non-null   object
#  29  neighbourhood_group_cleansed                  6882 non-null   object
#  30  latitude                                      6882 non-null   float64
#  31  longitude                                     6882 non-null   float64
#  32  property_type                                 6882 non-null   object
#  33  room_type                                     6882 non-null   object
#  34  accommodates                                  6882 non-null   int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                6882 non-null   object
#  37  bedrooms                                      0 non-null      float64
#  38  beds                                          6826 non-null   float64
#  39  amenities                                     6882 non-null   object
#  40  price                                         6504 non-null   object
#  41  minimum_nights                                6882 non-null   int64
#  42  maximum_nights                                6882 non-null   int64
#  43  minimum_minimum_nights                        6882 non-null   int64
#  44  maximum_minimum_nights                        6882 non-null   int64
#  45  minimum_maximum_nights                        6882 non-null   int64
#  46  maximum_maximum_nights                        6882 non-null   int64
#  47  minimum_nights_avg_ntm                        6882 non-null   float64
#  48  maximum_nights_avg_ntm                        6882 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              6504 non-null   object
#  51  availability_30                               6882 non-null   int64
#  52  availability_60                               6882 non-null   int64
#  53  availability_90                               6882 non-null   int64
#  54  availability_365                              6882 non-null   int64
#  55  calendar_last_scraped                         6882 non-null   object
#  56  number_of_reviews                             6882 non-null   int64
#  57  number_of_reviews_ltm                         6882 non-null   int64
#  58  number_of_reviews_l30d                        6882 non-null   int64
#  59  first_review                                  5809 non-null   object
#  60  last_review                                   5809 non-null   object
#  61  review_scores_rating                          5812 non-null   float64
#  62  review_scores_accuracy                        5812 non-null   float64
#  63  review_scores_cleanliness                     5812 non-null   float64
#  64  review_scores_checkin                         5812 non-null   float64
#  65  review_scores_communication                   5812 non-null   float64
#  66  review_scores_location                        5812 non-null   float64
#  67  review_scores_value                           5811 non-null   float64
#  68  license                                       5462 non-null   object
#  69  instant_bookable                              6882 non-null   object
#  70  calculated_host_listings_count                6882 non-null   int64
#  71  calculated_host_listings_count_entire_homes   6882 non-null   int64
#  72  calculated_host_listings_count_private_rooms  6882 non-null   int64
#  73  calculated_host_listings_count_shared_rooms   6882 non-null   int64
#  74  reviews_per_month                             5809 non-null   float64
# dtypes: float64(17), int64(23), object(35)
# memory usage: 3.9+ MB

# %% [markdown]
# ## Features selection

# %% [markdown]
# * The ultimate goal of our project is to predict the price of Airbnb room for customers by giving information they care about when looking for a rental. In this way, features that customers will probably be interested in, including room type, accommodates, neighborhood, review ratings and so on, were selected for further analysis.
# * As a result, all selected features are: neighborhood, room type, bathroom type, bedroom number, bathroom number, beds number, and review rating.
# * As some of our selected features were not explicitly listed in the raw dataset, features such as beds number, bedroom number and bathroom type will be extracted from columns like `name` and `bathrooms_text`.

# %%
selected_columns = ['id', 'name', 'neighbourhood_cleansed','room_type','accommodates','bathrooms_text','bedrooms', 'beds','review_scores_rating', 'price']

# %%
df = df_all[selected_columns]
df = df.rename(columns={'neighbourhood_cleansed': 'neighbourhood', 'review_scores_rating': 'rating'})
df.head()
# Out:
#      id                                               name   neighbourhood  \
# 0  6606  Guesthouse in Seattle · ★4.60 · 1 bedroom · 1 ...     Wallingford
# 1  9419  Rental unit in Seattle · ★4.72 · 1 bedroom · 1...      Georgetown
# 2  9531  Home in Seattle · ★4.97 · 2 bedrooms · 3 beds ...  Fairmount Park
# 3  9534  Guest suite in Seattle · ★4.99 · 2 bedrooms · ...  Fairmount Park
# 4  9596  Rental unit in Seattle · ★4.56 · 1 bedroom · 4...     Wallingford
#
#          room_type  accommodates  bathrooms_text  bedrooms  beds  rating  \
# 0  Entire home/apt             1          1 bath       NaN   1.0    4.60
# 1     Private room             2  3 shared baths       NaN   1.0    4.72
# 2  Entire home/apt             4          1 bath       NaN   3.0    4.97
# 3  Entire home/apt             3          1 bath       NaN   2.0    4.99
# 4  Entire home/apt             4          1 bath       NaN   4.0    4.56
#
#      price
# 0   $99.00
# 1   $67.00
# 2  $184.00
# 3  $155.00
# 4      NaN

# %% [markdown]
# ## Handling of missing values and feature exctracting

# %% [markdown]
# * We will give the prediction of `price` in this project, since 378 of 6882 rooms have missing `price` values, these records will be simply removed from further analysis.
# * Primary analysis for all selected features are listed below:
#     * neighborhood: explicitly included in the `neighbourhood` column
#     * room type: explicitly included in the `room_type` column
#     * bedroom number: implicitly included in the `name` column
#     * beds number: implicitly included in the `name` column
#     * bathroom type: implicitly included in the `bathrooms_text` column
#     * bathroom number: implicitly included in the `bathrooms_text` column
#     * review rating: some of rating scores were missing from `review_scores_rating` column, for these records, we will try to extract the rating value from `name` column

# %%
df.isna().sum()
# Out:
# id                   0
# name                 0
# neighbourhood        0
# room_type            0
# accommodates         0
# bathrooms_text       0
# bedrooms          6882
# beds                56
# rating            1070
# price              378
# dtype: int64

# %%
# NA records in `price` will be removed
df = df.loc[df["price"].notnull(), :]

# %%
# some information are implicitly included within the `name` column 
df.iloc[1]['name']
# Out:
# 'Rental unit in Seattle · ★4.72 · 1 bedroom · 1 bed · 3 shared baths'

# %% [markdown]
# * Handling of `rating`, `bed number` and `bedroom number`

# %%
rating_ptn = r'★\s*(\d+\.\d+)'
bedroom_ptn = r'(\d+)\s+bedroom'
bed_ptn = r'(\d+)\s+bed'


def fillna_rating(idx, row):
    '''
    fill rating with information extracted from `name` if `review_scores_rating` is na
    '''
    if pd.isna(row['rating']):
        rating = re.findall(rating_ptn, row['name'])
        df.loc[idx, 'rating'] = float(rating[0]) if rating else -1


def fillna_bedroom(idx, row):
    '''
    fill bedroom with information extracted from `name` if `bedrooms` is na
    '''
    if pd.isna(row['bedrooms']):
        if 'studio' in row['name'].lower():
            df.loc[idx, 'bedrooms'] = 0
        else:
            bedrooms = re.findall(bedroom_ptn, row['name'])
            df.loc[idx, 'bedrooms'] = int(bedrooms[0]) if bedrooms else -1


def fillna_bed(idx, row):
    '''
    fill beds with information extracted from `name` if `beds` is na
    '''
    if pd.isna(row['beds']):
        beds = re.findall(bed_ptn, row['name'])
        df.loc[idx, 'beds'] = int(beds[0]) if beds else -1    


for idx, row in df.iterrows():
    fillna_rating(idx, row)
    fillna_bedroom(idx, row)
    fillna_bed(idx, row)

# %%
df.head()
# Out:
#      id                                               name   neighbourhood  \
# 0  6606  Guesthouse in Seattle · ★4.60 · 1 bedroom · 1 ...     Wallingford
# 1  9419  Rental unit in Seattle · ★4.72 · 1 bedroom · 1...      Georgetown
# 2  9531  Home in Seattle · ★4.97 · 2 bedrooms · 3 beds ...  Fairmount Park
# 3  9534  Guest suite in Seattle · ★4.99 · 2 bedrooms · ...  Fairmount Park
# 5  9909  Home in Seattle · ★4.80 · 2 bedrooms · 2 beds ...  Fairmount Park
#
#          room_type  accommodates  bathrooms_text  bedrooms  beds  rating  \
# 0  Entire home/apt             1          1 bath       1.0   1.0    4.60
# 1     Private room             2  3 shared baths       1.0   1.0    4.72
# 2  Entire home/apt             4          1 bath       2.0   3.0    4.97
# 3  Entire home/apt             3          1 bath       2.0   2.0    4.99
# 5  Entire home/apt             4          1 bath       2.0   2.0    4.80
#
#      price
# 0   $99.00
# 1   $67.00
# 2  $184.00
# 3  $155.00
# 5  $228.00

# %% [markdown]
# * Handling of `bathroom number` and `bath type`

# %%
df['bathrooms_text'].unique()
# Out:
# array(['1 bath', '3 shared baths', '1.5 baths', '4 shared baths',
#        '1 shared bath', '1 private bath', '2 baths', '3 baths', '4 baths',
#        '2.5 baths', '1.5 shared baths', 'Shared half-bath',
#        '2 shared baths', '3.5 baths', 'Half-bath', '2.5 shared baths',
#        '3.5 shared baths', '0 shared baths', '4.5 baths',
#        '16 shared baths', '0 baths', '6 baths', 'Private half-bath',
#        '6.5 baths', '7 baths', '5.5 baths', '5 baths'], dtype=object)

# %% [markdown]
# * Bathroom numbers and types are primarily extracted from `bathrooms_text` column.

# %%
bath_txt_ptn = r'(\d+\.?\d*)'

def fill_bath(row):
    bath = re.findall(bath_txt_ptn, row)
    return float(bath[0]) if bath else -1


def fill_bath_type(text):
    if 'shared' in text:
        return 'shared'
    elif 'private' in text:
        return 'private'
    elif 'half-bath' in text:
        return 'half-bath'
    else:
        return 'standard'


df['bathrooms'] = df['bathrooms_text'].apply(fill_bath)
df['bath_type'] = df['bathrooms_text'].apply(fill_bath_type)

# %%
df.head()
# Out:
#      id                                               name   neighbourhood  \
# 0  6606  Guesthouse in Seattle · ★4.60 · 1 bedroom · 1 ...     Wallingford
# 1  9419  Rental unit in Seattle · ★4.72 · 1 bedroom · 1...      Georgetown
# 2  9531  Home in Seattle · ★4.97 · 2 bedrooms · 3 beds ...  Fairmount Park
# 3  9534  Guest suite in Seattle · ★4.99 · 2 bedrooms · ...  Fairmount Park
# 5  9909  Home in Seattle · ★4.80 · 2 bedrooms · 2 beds ...  Fairmount Park
#
#          room_type  accommodates  bathrooms_text  bedrooms  beds  rating  \
# 0  Entire home/apt             1          1 bath       1.0   1.0    4.60
# 1     Private room             2  3 shared baths       1.0   1.0    4.72
# 2  Entire home/apt             4          1 bath       2.0   3.0    4.97
# 3  Entire home/apt             3          1 bath       2.0   2.0    4.99
# 5  Entire home/apt             4          1 bath       2.0   2.0    4.80
#
#      price  bathrooms bath_type
# 0   $99.00        1.0  standard
# 1   $67.00        3.0    shared
# 2  $184.00        1.0  standard
# 3  $155.00        1.0  standard
# 5  $228.00        1.0  standard

# %%
# NA values are now marked as -1

df = df.loc[(df['rating'] != -1) 
            & (df['bedrooms'] != -1) 
            & (df['beds'] != -1)
            & (df['bathrooms'] != -1), :]

# %%
df.isna().sum()
# Out:
# id                0
# name              0
# neighbourhood     0
# room_type         0
# accommodates      0
# bathrooms_text    0
# bedrooms          0
# beds              0
# rating            0
# price             0
# bathrooms         0
# bath_type         0
# dtype: int64

# %%
df.shape
# Out:
# (5475, 12)

# %%
df.describe()
# Out:
#                  id  accommodates     bedrooms         beds       rating  \
# count  5.475000e+03   5475.000000  5475.000000  5475.000000  5475.000000
# mean   3.416739e+17      4.180457     1.661553     2.237443     4.795353
# std    4.063029e+17      2.600543     1.186012     1.504671     0.356755
# min    6.606000e+03      1.000000     0.000000     1.000000     1.000000
# 25%    2.529550e+07      2.000000     1.000000     1.000000     4.760000
# 50%    5.163902e+07      4.000000     1.000000     2.000000     4.890000
# 75%    7.538532e+17      6.000000     2.000000     3.000000     4.980000
# max    1.041325e+18     16.000000    13.000000    16.000000     5.000000
#
#          bathrooms
# count  5475.000000
# mean      1.435251
# std       0.811386
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      16.000000

# %%
columns_to_keep = ['accommodates', 'bedrooms', 'beds', 'bathrooms', 'rating',
                  'neighbourhood', 'room_type', 'bath_type', 'price']
df = df[columns_to_keep]
df.head()
# Out:
#    accommodates  bedrooms  beds  bathrooms  rating   neighbourhood  \
# 0             1       1.0   1.0        1.0    4.60     Wallingford
# 1             2       1.0   1.0        3.0    4.72      Georgetown
# 2             4       2.0   3.0        1.0    4.97  Fairmount Park
# 3             3       2.0   2.0        1.0    4.99  Fairmount Park
# 5             4       2.0   2.0        1.0    4.80  Fairmount Park
#
#          room_type bath_type    price
# 0  Entire home/apt  standard   $99.00
# 1     Private room    shared   $67.00
# 2  Entire home/apt  standard  $184.00
# 3  Entire home/apt  standard  $155.00
# 5  Entire home/apt  standard  $228.00

# %% [markdown]
# ## Data type and encoding

# %% [markdown]
# * `price` has to be float type rather than string
# * Encoding categorical features like `neighbourhood` in one-hot pattern

# %%
df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5475 entries, 0 to 6814
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   accommodates   5475 non-null   int64
#  1   bedrooms       5475 non-null   float64
#  2   beds           5475 non-null   float64
#  3   bathrooms      5475 non-null   float64
#  4   rating         5475 non-null   float64
#  5   neighbourhood  5475 non-null   object
#  6   room_type      5475 non-null   object
#  7   bath_type      5475 non-null   object
#  8   price          5475 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 427.7+ KB

# %%
df_prim = df[df['price'] <= 4000]
df_prim.to_csv('./data/listing_primary.csv', index=False)

# %% [markdown]
# * Features including `neighbourhood`, `room_type` and `bath_type` are categorical data, we thus convert these values into one-hot encoding pattern.

# %%
df['neighbourhood'].unique()
# Out:
# array(['Wallingford', 'Georgetown', 'Fairmount Park', 'Whittier Heights',
#        'Sunset Hill', 'Eastlake', 'Fremont', 'Green Lake', 'Portage Bay',
#        'Phinney Ridge', 'Crown Hill', 'Columbia City', 'Lawton Park',
#        'North Queen Anne', 'West Queen Anne', 'First Hill', 'Broadway',
#        'North Admiral', 'International District', 'North Beacon Hill',
#        'Greenwood', 'Cedar Park', 'Mount Baker', 'Mann', 'Ravenna',
#        'Belltown', 'University District', 'Harrison/Denny-Blaine',
#        'South Delridge', 'Broadview', 'Maple Leaf', 'East Queen Anne',
#        'Atlantic', 'Highland Park', 'West Woodland', 'Laurelhurst',
#        'Haller Lake', 'Madison Park', 'Fauntleroy', 'Madrona',
#        'Loyal Heights', 'Gatewood', 'Leschi', 'Westlake', 'Adams',
#        'North Delridge', 'Bryant', 'Seward Park', 'Stevens',
#        'Central Business District', 'Pioneer Square', 'Pike-Market',
#        'Yesler Terrace', 'Alki', 'Bitter Lake', 'Lower Queen Anne',
#        'Windermere', 'Minor', 'Rainier Beach', 'Seaview',
#        'Victory Heights', 'Roosevelt', 'Dunlap', 'Matthews Beach',
#        'Southeast Magnolia', 'Genesee', 'Olympic Hills',
#        'North Beach/Blue Ridge', 'Mid-Beacon Hill', 'Brighton',
#        'Interbay', 'Briarcliff', 'Montlake', 'North College Park',
#        'View Ridge', 'Riverview', 'Pinehurst', 'Wedgwood', 'Meadowbrook',
#        'Rainier View', 'High Point', 'South Beacon Hill',
#        'Industrial District', 'South Park', 'South Lake Union', 'Roxhill',
#        'Arbor Heights', 'Holly Park'], dtype=object)

# %%
df['bath_type'].unique()
# Out:
# array(['standard', 'shared', 'private'], dtype=object)

# %%
df['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %%
df['room_type'] = df['room_type'].map({'Entire home/apt': 'entire', 
                                      'Private room': 'private', 
                                      'Shared room': 'shared', })

# %%
df_clean = pd.get_dummies(df, columns=['bath_type', 'room_type', 'neighbourhood'])
df_clean.head()
# Out:
#    accommodates  bedrooms  beds  bathrooms  rating  price  bath_type_private  \
# 0             1       1.0   1.0        1.0    4.60   99.0              False
# 1             2       1.0   1.0        3.0    4.72   67.0              False
# 2             4       2.0   3.0        1.0    4.97  184.0              False
# 3             3       2.0   2.0        1.0    4.99  155.0              False
# 5             4       2.0   2.0        1.0    4.80  228.0              False
#
#    bath_type_shared  bath_type_standard  room_type_entire  ...  \
# 0             False                True              True  ...
# 1              True               False             False  ...
# 2             False                True              True  ...
# 3             False                True              True  ...
# 5             False                True              True  ...
#
#    neighbourhood_Victory Heights  neighbourhood_View Ridge  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 5                          False                     False
#
#    neighbourhood_Wallingford  neighbourhood_Wedgwood  \
# 0                       True                   False
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 5                      False                   False
#
#    neighbourhood_West Queen Anne  neighbourhood_West Woodland  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 5                          False                        False
#
#    neighbourhood_Westlake  neighbourhood_Whittier Heights  \
# 0                   False                           False
# 1                   False                           False
# 2                   False                           False
# 3                   False                           False
# 5                   False                           False
#
#    neighbourhood_Windermere  neighbourhood_Yesler Terrace
# 0                     False                         False
# 1                     False                         False
# 2                     False                         False
# 3                     False                         False
# 5                     False                         False
#
# [5 rows x 100 columns]

# %% [markdown]
# * Cleaned data (df_clean) is dumped into disk for training out model

# %%
df_clean = df_clean[df_clean['price'] <= 4000]
df_clean.to_csv('./data/listing_cleaned.csv', index=False)

# %%
# dump a df with only one row to generate user input in Streamlit app
df_input = df_clean.iloc[0:1]
df_input = df_input.drop('price', axis=1)
df_input.to_csv('./data/default_input.csv', index=False)
