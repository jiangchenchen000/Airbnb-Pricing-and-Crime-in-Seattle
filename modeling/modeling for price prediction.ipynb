# %%
import numpy as np 
import pandas as pd
from scipy.stats import zscore
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1 Pre-process for modeling

# %% [markdown]
# ## 1.1 process with data frame

# %%
#import data
df= pd.read_csv('processedListingDATA(4 seasons).csv')
df.head()
# Out:
#      id  availability in one year                                        name  \
# 0  6606                       273         Fab, private seattle urban cottage!
# 1  9419                       336         Glorious sun room w/ memory foambed
# 2  9531                       176         The Adorable Sweet Orange Craftsman
# 3  9534                        39            The Coolest Tangerine Dream MIL!
# 4  9596                       125  the down home , spacious, central and fab!
#
#   neighbourhood_cleansed  latitude  longitude                property_type  \
# 0            Wallingford  47.65444 -122.33629            Entire guesthouse
# 1             Georgetown  47.55017 -122.31937  Private room in rental unit
# 2         Fairmount Park  47.55495 -122.38663                  Entire home
# 3         Fairmount Park  47.55627 -122.38607           Entire guest suite
# 4            Wallingford  47.65608 -122.33602           Entire rental unit
#
#          room_type  accommodates  bathrooms_text  bedrooms  beds  price  \
# 0  Entire home/apt             1          1 bath       1.0   1.0   99.0
# 1     Private room             2  3 shared baths       1.0   2.0   55.0
# 2  Entire home/apt             4          1 bath       2.0   3.0  175.0
# 3  Entire home/apt             3          1 bath       2.0   2.0  135.0
# 4  Entire home/apt             4          1 bath       1.0   4.0  130.0
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                159                  4.61                    4.67
# 1                175                  4.70                    4.78
# 2                 71                  4.96                    4.99
# 3                 73                  4.99                    4.99
# 4                 97                  4.56                    4.55
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.67                   4.83
# 1                       4.73                   4.93
# 2                       4.97                   4.99
# 3                       4.99                   5.00
# 4                       4.50                   4.80
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.76                    4.88                 4.57
# 1                         4.88                    4.65                 4.65
# 2                         4.96                    4.97                 4.90
# 3                         4.99                    4.96                 4.94
# 4                         4.66                    4.91                 4.56
#
#    bathroom_count bathroom_type  Total crime
# 0             1.0      standard      19411.0
# 1             3.0        shared      10434.0
# 2             1.0      standard       6776.0
# 3             1.0      standard       6776.0
# 4             1.0      standard      19411.0

# %%
#select dependent variables and independent variable.
selected_columns = ['price','neighbourhood_cleansed','property_type','room_type','accommodates','bedrooms','beds'
                    ,'bathroom_count','bathroom_type']
df = df[selected_columns]
df.head()
# Out:
#    price neighbourhood_cleansed                property_type        room_type  \
# 0   99.0            Wallingford            Entire guesthouse  Entire home/apt
# 1   55.0             Georgetown  Private room in rental unit     Private room
# 2  175.0         Fairmount Park                  Entire home  Entire home/apt
# 3  135.0         Fairmount Park           Entire guest suite  Entire home/apt
# 4  130.0            Wallingford           Entire rental unit  Entire home/apt
#
#    accommodates  bedrooms  beds  bathroom_count bathroom_type
# 0             1       1.0   1.0             1.0      standard
# 1             2       1.0   2.0             3.0        shared
# 2             4       2.0   3.0             1.0      standard
# 3             3       2.0   2.0             1.0      standard
# 4             4       1.0   4.0             1.0      standard

# %%
#missing value checking
na_counts = df.isna().sum()
na_counts
# Out:
# price                     0
# neighbourhood_cleansed    0
# property_type             0
# room_type                 0
# accommodates              0
# bedrooms                  0
# beds                      0
# bathroom_count            0
# bathroom_type             0
# dtype: int64

# %% [markdown]
# ## 1.2 process with outlier

# %%
df.describe()
# Out:
#              price  accommodates     bedrooms         beds  bathroom_count
# count  8218.000000   8218.000000  8218.000000  8218.000000     8218.000000
# mean    173.988927      4.132149     1.716719     2.195546        1.443599
# std     181.662215      2.614925     1.159356     1.506012        0.762036
# min      10.000000      1.000000     0.000000     1.000000        0.000000
# 25%      95.000000      2.000000     1.000000     1.000000        1.000000
# 50%     137.000000      4.000000     1.000000     2.000000        1.000000
# 75%     200.000000      6.000000     2.000000     3.000000        2.000000
# max    4000.000000     16.000000    11.000000    16.000000       16.000000

# %%
columns_to_plot = ['accommodates', 'bedrooms', 'beds', 'bathroom_count', 'price']

plt.figure(figsize=(15, 10))

for i, column in enumerate(columns_to_plot):
    plt.subplot(len(columns_to_plot), 1, i + 1) 
    sns.boxplot(x=df[column])
    plt.title(f'Box plot of {column}')

plt.tight_layout()
plt.show()

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_IQR = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)].index
df_no_outlier_IQR = df.drop(outliers_IQR)

# %%
plt.figure(figsize=(15, 10))

for i, column in enumerate(columns_to_plot):
    plt.subplot(len(columns_to_plot), 1, i + 1) 
    sns.boxplot(x=df_no_outlier_IQR[column])
    plt.title(f'Box plot of {column}')

plt.tight_layout()
plt.show()

# %%
df_z = df
df_z['z_score'] = zscore(df['price'])
z_score_threshold = 3
outliers_z = df_z[abs(df_z['z_score']) > z_score_threshold].index
df_no_outlier_z = df_z.drop(outliers_z)
df_z = df_no_outlier_z.drop(columns=['z_score'])

# %%
plt.figure(figsize=(15, 10))

for i, column in enumerate(columns_to_plot):
    plt.subplot(len(columns_to_plot), 1, i + 1) 
    sns.boxplot(x=df_z[column])
    plt.title(f'Box plot of {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# When the data is skewed to the right (positively skewed), it means that there are a number of exceptionally high values. the IQR method might not be the best choice to identify outliers because it could eliminate many data points that are naturally occurring in the distribution's tail. This is because IQR is more sensitive to skewness and might consider many of these data points as outliers. in practice, Z-score can sometimes handle skewed data better than IQR since it takes into account the mean and standard deviation, which are influenced by skewness.

# %% [markdown]
# # 2 prediction model for price with all columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error, r2_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.feature_selection import mutual_info_regression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# %% [markdown]
# ## 2.1 additional process data

# %%
# Convert categorical data into boolean and remove unnecessary data
df_encoded = df_z.copy()

categorical_columns = ['neighbourhood_cleansed', 'property_type', 'bathroom_type','room_type']

for column in categorical_columns:
    dummies = pd.get_dummies(df_encoded[column], prefix=column)
    df_encoded = pd.concat([df_encoded, dummies], axis=1)

df_encoded = df_encoded.drop(columns=categorical_columns)

df_encoded.head()
# Out:
#    price  accommodates  bedrooms  beds  bathroom_count  \
# 0   99.0             1       1.0   1.0             1.0
# 1   55.0             2       1.0   2.0             3.0
# 2  175.0             4       2.0   3.0             1.0
# 3  135.0             3       2.0   2.0             1.0
# 4  130.0             4       1.0   4.0             1.0
#
#    neighbourhood_cleansed_Adams  neighbourhood_cleansed_Alki  \
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                         False                        False
# 4                         False                        False
#
#    neighbourhood_cleansed_Arbor Heights  neighbourhood_cleansed_Atlantic  \
# 0                                 False                            False
# 1                                 False                            False
# 2                                 False                            False
# 3                                 False                            False
# 4                                 False                            False
#
#    neighbourhood_cleansed_Belltown  neighbourhood_cleansed_Bitter Lake  \
# 0                            False                               False
# 1                            False                               False
# 2                            False                               False
# 3                            False                               False
# 4                            False                               False
#
#    neighbourhood_cleansed_Briarcliff  neighbourhood_cleansed_Brighton  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
#
#    neighbourhood_cleansed_Broadview  neighbourhood_cleansed_Broadway  \
# 0                             False                            False
# 1                             False                            False
# 2                             False                            False
# 3                             False                            False
# 4                             False                            False
#
#    neighbourhood_cleansed_Bryant  neighbourhood_cleansed_Cedar Park  \
# 0                          False                              False
# 1                          False                              False
# 2                          False                              False
# 3                          False                              False
# 4                          False                              False
#
#    neighbourhood_cleansed_Central Business District  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    neighbourhood_cleansed_Columbia City  neighbourhood_cleansed_Crown Hill  \
# 0                                 False                              False
# 1                                 False                              False
# 2                                 False                              False
# 3                                 False                              False
# 4                                 False                              False
#
#    neighbourhood_cleansed_Dunlap  neighbourhood_cleansed_East Queen Anne  \
# 0                          False                                   False
# 1                          False                                   False
# 2                          False                                   False
# 3                          False                                   False
# 4                          False                                   False
#
#    neighbourhood_cleansed_Eastlake  neighbourhood_cleansed_Fairmount Park  \
# 0                            False                                  False
# 1                            False                                  False
# 2                            False                                   True
# 3                            False                                   True
# 4                            False                                  False
#
#    neighbourhood_cleansed_Fauntleroy  neighbourhood_cleansed_First Hill  \
# 0                              False                              False
# 1                              False                              False
# 2                              False                              False
# 3                              False                              False
# 4                              False                              False
#
#    neighbourhood_cleansed_Fremont  neighbourhood_cleansed_Gatewood  \
# 0                           False                            False
# 1                           False                            False
# 2                           False                            False
# 3                           False                            False
# 4                           False                            False
#
#    neighbourhood_cleansed_Genesee  neighbourhood_cleansed_Georgetown  \
# 0                           False                              False
# 1                           False                               True
# 2                           False                              False
# 3                           False                              False
# 4                           False                              False
#
#    neighbourhood_cleansed_Green Lake  neighbourhood_cleansed_Greenwood  \
# 0                              False                             False
# 1                              False                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
#
#    neighbourhood_cleansed_Haller Lake  neighbourhood_cleansed_Harbor Island  \
# 0                               False                                 False
# 1                               False                                 False
# 2                               False                                 False
# 3                               False                                 False
# 4                               False                                 False
#
#    neighbourhood_cleansed_Harrison/Denny-Blaine  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    neighbourhood_cleansed_High Point  neighbourhood_cleansed_Highland Park  \
# 0                              False                                 False
# 1                              False                                 False
# 2                              False                                 False
# 3                              False                                 False
# 4                              False                                 False
#
#    neighbourhood_cleansed_Holly Park  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    neighbourhood_cleansed_Industrial District  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    neighbourhood_cleansed_Interbay  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    neighbourhood_cleansed_International District  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    neighbourhood_cleansed_Laurelhurst  neighbourhood_cleansed_Lawton Park  \
# 0                               False                               False
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                               False                               False
#
#    neighbourhood_cleansed_Leschi  neighbourhood_cleansed_Lower Queen Anne  \
# 0                          False                                    False
# 1                          False                                    False
# 2                          False                                    False
# 3                          False                                    False
# 4                          False                                    False
#
#    neighbourhood_cleansed_Loyal Heights  neighbourhood_cleansed_Madison Park  \
# 0                                 False                                False
# 1                                 False                                False
# 2                                 False                                False
# 3                                 False                                False
# 4                                 False                                False
#
#    neighbourhood_cleansed_Madrona  neighbourhood_cleansed_Mann  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
#
#    neighbourhood_cleansed_Maple Leaf  neighbourhood_cleansed_Matthews Beach  \
# 0                              False                                  False
# 1                              False                                  False
# 2                              False                                  False
# 3                              False                                  False
# 4                              False                                  False
#
#    neighbourhood_cleansed_Meadowbrook  neighbourhood_cleansed_Mid-Beacon Hill  \
# 0                               False                                   False
# 1                               False                                   False
# 2                               False                                   False
# 3                               False                                   False
# 4                               False                                   False
#
#    neighbourhood_cleansed_Minor  neighbourhood_cleansed_Montlake  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
#
#    neighbourhood_cleansed_Mount Baker  neighbourhood_cleansed_North Admiral  \
# 0                               False                                 False
# 1                               False                                 False
# 2                               False                                 False
# 3                               False                                 False
# 4                               False                                 False
#
#    neighbourhood_cleansed_North Beach/Blue Ridge  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    neighbourhood_cleansed_North Beacon Hill  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    neighbourhood_cleansed_North College Park  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    neighbourhood_cleansed_North Delridge  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    neighbourhood_cleansed_North Queen Anne  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    neighbourhood_cleansed_Olympic Hills  neighbourhood_cleansed_Phinney Ridge  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
#    neighbourhood_cleansed_Pike-Market  neighbourhood_cleansed_Pinehurst  \
# 0                               False                             False
# 1                               False                             False
# 2                               False                             False
# 3                               False                             False
# 4                               False                             False
#
#    neighbourhood_cleansed_Pioneer Square  neighbourhood_cleansed_Portage Bay  \
# 0                                  False                               False
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
#
#    neighbourhood_cleansed_Rainier Beach  neighbourhood_cleansed_Rainier View  \
# 0                                 False                                False
# 1                                 False                                False
# 2                                 False                                False
# 3                                 False                                False
# 4                                 False                                False
#
#    neighbourhood_cleansed_Ravenna  neighbourhood_cleansed_Riverview  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
#
#    neighbourhood_cleansed_Roosevelt  neighbourhood_cleansed_Roxhill  \
# 0                             False                           False
# 1                             False                           False
# 2                             False                           False
# 3                             False                           False
# 4                             False                           False
#
#    neighbourhood_cleansed_Seaview  neighbourhood_cleansed_Seward Park  \
# 0                           False                               False
# 1                           False                               False
# 2                           False                               False
# 3                           False                               False
# 4                           False                               False
#
#    neighbourhood_cleansed_South Beacon Hill  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    neighbourhood_cleansed_South Delridge  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    neighbourhood_cleansed_South Lake Union  neighbourhood_cleansed_South Park  \
# 0                                    False                              False
# 1                                    False                              False
# 2                                    False                              False
# 3                                    False                              False
# 4                                    False                              False
#
#    neighbourhood_cleansed_Southeast Magnolia  neighbourhood_cleansed_Stevens  \
# 0                                      False                           False
# 1                                      False                           False
# 2                                      False                           False
# 3                                      False                           False
# 4                                      False                           False
#
#    neighbourhood_cleansed_Sunset Hill  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#    neighbourhood_cleansed_University District  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    neighbourhood_cleansed_Victory Heights  neighbourhood_cleansed_View Ridge  \
# 0                                   False                              False
# 1                                   False                              False
# 2                                   False                              False
# 3                                   False                              False
# 4                                   False                              False
#
#    neighbourhood_cleansed_Wallingford  neighbourhood_cleansed_Wedgwood  \
# 0                                True                            False
# 1                               False                            False
# 2                               False                            False
# 3                               False                            False
# 4                                True                            False
#
#    neighbourhood_cleansed_West Queen Anne  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    neighbourhood_cleansed_West Woodland  neighbourhood_cleansed_Westlake  \
# 0                                 False                            False
# 1                                 False                            False
# 2                                 False                            False
# 3                                 False                            False
# 4                                 False                            False
#
#    neighbourhood_cleansed_Whittier Heights  neighbourhood_cleansed_Windermere  \
# 0                                    False                              False
# 1                                    False                              False
# 2                                    False                              False
# 3                                    False                              False
# 4                                    False                              False
#
#    neighbourhood_cleansed_Yesler Terrace  property_type_Barn  \
# 0                                  False               False
# 1                                  False               False
# 2                                  False               False
# 3                                  False               False
# 4                                  False               False
#
#    property_type_Boat  property_type_Bus  property_type_Camper/RV  \
# 0               False              False                    False
# 1               False              False                    False
# 2               False              False                    False
# 3               False              False                    False
# 4               False              False                    False
#
#    property_type_Casa particular  property_type_Entire bungalow  \
# 0                          False                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                          False
#
#    property_type_Entire cabin  property_type_Entire condo  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    property_type_Entire cottage  property_type_Entire guest suite  \
# 0                         False                             False
# 1                         False                             False
# 2                         False                             False
# 3                         False                              True
# 4                         False                             False
#
#    property_type_Entire guesthouse  property_type_Entire home  \
# 0                             True                      False
# 1                            False                      False
# 2                            False                       True
# 3                            False                      False
# 4                            False                      False
#
#    property_type_Entire loft  property_type_Entire place  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
#
#    property_type_Entire rental unit  property_type_Entire serviced apartment  \
# 0                             False                                    False
# 1                             False                                    False
# 2                             False                                    False
# 3                             False                                    False
# 4                              True                                    False
#
#    property_type_Entire townhouse  property_type_Entire vacation home  \
# 0                           False                               False
# 1                           False                               False
# 2                           False                               False
# 3                           False                               False
# 4                           False                               False
#
#    property_type_Entire villa  property_type_Farm stay  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
#
#    property_type_Houseboat  property_type_Private room  \
# 0                    False                       False
# 1                    False                       False
# 2                    False                       False
# 3                    False                       False
# 4                    False                       False
#
#    property_type_Private room in bed and breakfast  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    property_type_Private room in boat  property_type_Private room in bungalow  \
# 0                               False                                   False
# 1                               False                                   False
# 2                               False                                   False
# 3                               False                                   False
# 4                               False                                   False
#
#    property_type_Private room in casa particular  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    property_type_Private room in condo  property_type_Private room in cottage  \
# 0                                False                                  False
# 1                                False                                  False
# 2                                False                                  False
# 3                                False                                  False
# 4                                False                                  False
#
#    property_type_Private room in earthen home  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    property_type_Private room in guest suite  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    property_type_Private room in guesthouse  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    property_type_Private room in home  property_type_Private room in hostel  \
# 0                               False                                 False
# 1                               False                                 False
# 2                               False                                 False
# 3                               False                                 False
# 4                               False                                 False
#
#    property_type_Private room in loft  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#    property_type_Private room in rental unit  \
# 0                                      False
# 1                                       True
# 2                                      False
# 3                                      False
# 4                                      False
#
#    property_type_Private room in resort  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    property_type_Private room in serviced apartment  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    property_type_Private room in tiny home  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    property_type_Private room in townhouse  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    property_type_Private room in treehouse  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    property_type_Private room in villa  property_type_Room in aparthotel  \
# 0                                False                             False
# 1                                False                             False
# 2                                False                             False
# 3                                False                             False
# 4                                False                             False
#
#    property_type_Room in boutique hotel  property_type_Room in hotel  \
# 0                                 False                        False
# 1                                 False                        False
# 2                                 False                        False
# 3                                 False                        False
# 4                                 False                        False
#
#    property_type_Shared room  property_type_Shared room in condo  \
# 0                      False                               False
# 1                      False                               False
# 2                      False                               False
# 3                      False                               False
# 4                      False                               False
#
#    property_type_Shared room in home  property_type_Shared room in hostel  \
# 0                              False                                False
# 1                              False                                False
# 2                              False                                False
# 3                              False                                False
# 4                              False                                False
#
#    property_type_Shared room in loft  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    property_type_Shared room in rental unit  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    property_type_Shared room in townhouse  property_type_Tent  \
# 0                                   False               False
# 1                                   False               False
# 2                                   False               False
# 3                                   False               False
# 4                                   False               False
#
#    property_type_Tiny home  bathroom_type_half-bath  bathroom_type_private  \
# 0                    False                    False                  False
# 1                    False                    False                  False
# 2                    False                    False                  False
# 3                    False                    False                  False
# 4                    False                    False                  False
#
#    bathroom_type_shared  bathroom_type_standard  room_type_Entire home/apt  \
# 0                 False                    True                       True
# 1                  True                   False                      False
# 2                 False                    True                       True
# 3                 False                    True                       True
# 4                 False                    True                       True
#
#    room_type_Private room  room_type_Shared room
# 0                   False                  False
# 1                    True                  False
# 2                   False                  False
# 3                   False                  False
# 4                   False                  False

# %%
print(df_encoded.shape)

default_input = df_encoded.drop("price", axis=1)
default_input = default_input.iloc[0:1]
default_input.to_csv('default_input_opt.csv', index=False)
# Out:
# (8144, 154)

# %%
# split trainning and testing data
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ## 2.2 models and evaluation

# %%
X = df_encoded.drop('price', axis=1)
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}

metrics = {
    "Model": [],
    "RMSE": [],
    "MAE": [],
    "R2": []
}

for name, model in models.items():
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    metrics["Model"].append(name)
    metrics["RMSE"].append(rmse)
    metrics["MAE"].append(mae)
    metrics["R2"].append(r2)
    
stat_df_all_columns = pd.DataFrame(metrics)
stat_df_all_columns
# Out:
#                Model          RMSE           MAE            R2
# 0  Linear Regression  1.412782e+12  7.273133e+10 -1.843349e+20
# 1      Random Forest  7.534601e+01  4.850271e+01  4.757024e-01
# 2  Gradient Boosting  7.204973e+01  4.789198e+01  5.205735e-01

# %% [markdown]
# # 3 impove model

# %% [markdown]
# ## 3.1 optimal MLR

# %% [markdown]
# ### 3.1.1 MI scores for columns

# %%
X = df_encoded.drop(columns=['price'])
y = df_encoded['price']
mi_scores = mutual_info_regression(X, y)
mi_scores_series = pd.Series(mi_scores, index=X.columns, name="MI Scores")
mi_scores_series = mi_scores_series.sort_values(ascending=False)
mi_scores_series
# Out:
# accommodates                                        0.315943
# bedrooms                                            0.267888
# beds                                                0.243316
# bathroom_count                                      0.220286
# room_type_Entire home/apt                           0.175740
# room_type_Private room                              0.173073
# property_type_Private room in home                  0.124739
# bathroom_type_standard                              0.117685
# bathroom_type_shared                                0.087897
# property_type_Entire home                           0.084865
# property_type_Entire rental unit                    0.035875
# property_type_Entire townhouse                      0.029371
# property_type_Entire guest suite                    0.026696
# property_type_Private room in rental unit           0.020389
# bathroom_type_private                               0.019124
# neighbourhood_cleansed_Belltown                     0.017520
# neighbourhood_cleansed_Fremont                      0.016836
# neighbourhood_cleansed_Haller Lake                  0.015534
# neighbourhood_cleansed_Pioneer Square               0.014250
# neighbourhood_cleansed_Lower Queen Anne             0.014157
# neighbourhood_cleansed_University District          0.014153
# property_type_Entire guesthouse                     0.013763
# neighbourhood_cleansed_Highland Park                0.013391
# property_type_Shared room                           0.012295
# neighbourhood_cleansed_Yesler Terrace               0.011386
# property_type_Private room in townhouse             0.011109
# neighbourhood_cleansed_Holly Park                   0.010988
# neighbourhood_cleansed_Central Business District    0.010793
# neighbourhood_cleansed_Madison Park                 0.010783
# property_type_Private room in bed and breakfast     0.010658
# neighbourhood_cleansed_Briarcliff                   0.010309
# neighbourhood_cleansed_Broadway                     0.009974
# neighbourhood_cleansed_South Park                   0.009459
# neighbourhood_cleansed_Riverview                    0.008296
# neighbourhood_cleansed_Greenwood                    0.008252
# property_type_Private room in resort                0.008095
# property_type_Entire loft                           0.007813
# neighbourhood_cleansed_Whittier Heights             0.007719
# neighbourhood_cleansed_Ravenna                      0.007609
# neighbourhood_cleansed_Rainier Beach                0.007034
# neighbourhood_cleansed_Interbay                     0.006934
# neighbourhood_cleansed_Stevens                      0.006832
# neighbourhood_cleansed_Montlake                     0.006608
# neighbourhood_cleansed_Phinney Ridge                0.006391
# neighbourhood_cleansed_North College Park           0.006348
# property_type_Entire serviced apartment             0.006329
# property_type_Private room                          0.006265
# neighbourhood_cleansed_South Lake Union             0.006235
# property_type_Houseboat                             0.005767
# property_type_Tiny home                             0.005567
# neighbourhood_cleansed_Madrona                      0.005384
# bathroom_type_half-bath                             0.005328
# neighbourhood_cleansed_Leschi                       0.005074
# property_type_Private room in condo                 0.005016
# neighbourhood_cleansed_Harrison/Denny-Blaine        0.004918
# neighbourhood_cleansed_West Queen Anne              0.004667
# neighbourhood_cleansed_Cedar Park                   0.004448
# neighbourhood_cleansed_Southeast Magnolia           0.004382
# neighbourhood_cleansed_Mann                         0.004280
# neighbourhood_cleansed_North Queen Anne             0.004223
# property_type_Bus                                   0.003398
# property_type_Entire vacation home                  0.003371
# neighbourhood_cleansed_View Ridge                   0.002637
# room_type_Shared room                               0.002618
# property_type_Private room in earthen home          0.002558
# property_type_Entire condo                          0.002037
# property_type_Room in aparthotel                    0.001903
# neighbourhood_cleansed_Bryant                       0.001672
# property_type_Private room in guesthouse            0.001623
# neighbourhood_cleansed_Fairmount Park               0.001531
# property_type_Private room in boat                  0.001511
# neighbourhood_cleansed_Green Lake                   0.001397
# property_type_Entire place                          0.001306
# neighbourhood_cleansed_Broadview                    0.001229
# neighbourhood_cleansed_Portage Bay                  0.001042
# property_type_Camper/RV                             0.001026
# property_type_Shared room in home                   0.000981
# neighbourhood_cleansed_Laurelhurst                  0.000892
# neighbourhood_cleansed_Minor                        0.000813
# neighbourhood_cleansed_Dunlap                       0.000533
# neighbourhood_cleansed_Atlantic                     0.000491
# property_type_Private room in cottage               0.000371
# property_type_Casa particular                       0.000249
# neighbourhood_cleansed_Industrial District          0.000222
# property_type_Room in hotel                         0.000218
# neighbourhood_cleansed_Pinehurst                    0.000171
# property_type_Private room in loft                  0.000000
# property_type_Private room in guest suite           0.000000
# neighbourhood_cleansed_Eastlake                     0.000000
# property_type_Private room in casa particular       0.000000
# neighbourhood_cleansed_East Queen Anne              0.000000
# property_type_Private room in bungalow              0.000000
# property_type_Private room in hostel                0.000000
# neighbourhood_cleansed_Columbia City                0.000000
# neighbourhood_cleansed_Crown Hill                   0.000000
# property_type_Shared room in rental unit            0.000000
# neighbourhood_cleansed_Adams                        0.000000
# neighbourhood_cleansed_Alki                         0.000000
# neighbourhood_cleansed_Arbor Heights                0.000000
# neighbourhood_cleansed_Bitter Lake                  0.000000
# neighbourhood_cleansed_Brighton                     0.000000
# property_type_Tent                                  0.000000
# property_type_Shared room in townhouse              0.000000
# property_type_Shared room in loft                   0.000000
# property_type_Private room in serviced apartment    0.000000
# property_type_Shared room in hostel                 0.000000
# property_type_Shared room in condo                  0.000000
# property_type_Room in boutique hotel                0.000000
# property_type_Private room in villa                 0.000000
# property_type_Private room in treehouse             0.000000
# neighbourhood_cleansed_First Hill                   0.000000
# property_type_Private room in tiny home             0.000000
# neighbourhood_cleansed_Fauntleroy                   0.000000
# neighbourhood_cleansed_Georgetown                   0.000000
# property_type_Farm stay                             0.000000
# neighbourhood_cleansed_South Beacon Hill            0.000000
# neighbourhood_cleansed_Victory Heights              0.000000
# neighbourhood_cleansed_Meadowbrook                  0.000000
# neighbourhood_cleansed_Sunset Hill                  0.000000
# neighbourhood_cleansed_Mid-Beacon Hill              0.000000
# neighbourhood_cleansed_Mount Baker                  0.000000
# neighbourhood_cleansed_North Admiral                0.000000
# neighbourhood_cleansed_North Beach/Blue Ridge       0.000000
# neighbourhood_cleansed_Seward Park                  0.000000
# neighbourhood_cleansed_Wallingford                  0.000000
# neighbourhood_cleansed_Seaview                      0.000000
# neighbourhood_cleansed_Roxhill                      0.000000
# neighbourhood_cleansed_Roosevelt                    0.000000
# neighbourhood_cleansed_North Beacon Hill            0.000000
# neighbourhood_cleansed_North Delridge               0.000000
# neighbourhood_cleansed_Rainier View                 0.000000
# neighbourhood_cleansed_Olympic Hills                0.000000
# neighbourhood_cleansed_Matthews Beach               0.000000
# neighbourhood_cleansed_Wedgwood                     0.000000
# property_type_Entire villa                          0.000000
# property_type_Entire cabin                          0.000000
# neighbourhood_cleansed_Gatewood                     0.000000
# neighbourhood_cleansed_Genesee                      0.000000
# neighbourhood_cleansed_Pike-Market                  0.000000
# neighbourhood_cleansed_Harbor Island                0.000000
# neighbourhood_cleansed_High Point                   0.000000
# neighbourhood_cleansed_International District       0.000000
# property_type_Entire cottage                        0.000000
# property_type_Entire bungalow                       0.000000
# neighbourhood_cleansed_Maple Leaf                   0.000000
# property_type_Boat                                  0.000000
# property_type_Barn                                  0.000000
# neighbourhood_cleansed_Lawton Park                  0.000000
# neighbourhood_cleansed_Windermere                   0.000000
# neighbourhood_cleansed_Loyal Heights                0.000000
# neighbourhood_cleansed_Westlake                     0.000000
# neighbourhood_cleansed_West Woodland                0.000000
# neighbourhood_cleansed_South Delridge               0.000000
# Name: MI Scores, dtype: float64

# %% [markdown]
# ### 3.1.2 MLR with selected columns

# %%
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
model = LinearRegression()

model.fit(X_train, y_train)
y_pred_before = model.predict(X_test)
rmse_before = mean_squared_error(y_test, y_pred_before, squared=False)
mae_before = mean_absolute_error(y_test, y_pred_before)
r2_before = r2_score(y_test, y_pred_before)

X_optimized = df_encoded[['bedrooms', 'accommodates', 'beds', 'bathroom_count', 'room_type_Entire home/apt',
                          'room_type_Private room', 'property_type_Private room in home', 'bathroom_type_standard',
                          'property_type_Private room in home', 'bathroom_type_shared']]
y_optimized = df_encoded['price']
X_train_opt, X_test_opt, y_train_opt, y_test_opt = train_test_split(X_optimized, y_optimized, test_size=0.30, random_state=42)

model.fit(X_train_opt, y_train_opt)
y_pred_after = model.predict(X_test_opt)
rmse_after = mean_squared_error(y_test_opt, y_pred_after, squared=False)
mae_after = mean_absolute_error(y_test_opt, y_pred_after)
r2_after = r2_score(y_test_opt, y_pred_after)

results = pd.DataFrame({
    'Model': ['MLR Before Optimization', 'MLR After Optimization'],
    'RMSE': [rmse_before, rmse_after],
    'MAE': [mae_before, mae_after],
    'R2': [r2_before, r2_after]
})

results
# Out:
#                      Model          RMSE           MAE            R2
# 0  MLR Before Optimization  1.412782e+12  7.273133e+10 -1.843349e+20
# 1   MLR After Optimization  7.798860e+01  5.202343e+01  4.382803e-01

# %% [markdown]
# ## 3.2 optimal RF

# %% [markdown]
# ### 3.2.1 FInd optimal RF by using random search (run might take long time)

# %%
# split trainning and testing data
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

rf_model = RandomForestRegressor(random_state=42)

param_distributions = {
    'n_estimators': randint(100, 500),
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': randint(2, 20)
}

random_search = RandomizedSearchCV(estimator=rf_model, param_distributions=param_distributions, n_iter=10, cv=5, scoring='neg_mean_squared_error', verbose=1, random_state=42)
random_search.fit(X_train, y_train)

y_pred_random = random_search.best_estimator_.predict(X_test)

rmse_random = mean_squared_error(y_test, y_pred_random, squared=False)
mae_random = mean_absolute_error(y_test, y_pred_random)
r2_random = r2_score(y_test, y_pred_random)

print("Random Search Evaluation Metrics:")
print("RMSE:", rmse_random)
print("MAE:", mae_random)
print("R-squared:", r2_random)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Random Search Evaluation Metrics:
# RMSE: 72.38510003531219
# MAE: 47.12446663897357
# R-squared: 0.5160998431037114

# %%
#get the trained model into file for further prediction
best_params_grid_rs = random_search.best_estimator_
print("Best parameters:", best_params_grid_rs)

joblib.dump(best_params_grid_rs , 'best_rf_params_rs.joblib')
# Out:
# Best parameters: RandomForestRegressor(max_depth=20, min_samples_split=16, n_estimators=206,
#                       random_state=42)
# ['best_rf_params_rs.joblib']

# %% [markdown]
# ### 3.2.2 upload the optimal RF model we have trained above to predict

# %%
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

rf_model_before = RandomForestRegressor(random_state=42)

rf_model_before.fit(X_train, y_train)

y_pred_before = rf_model_before.predict(X_test)

rmse_before = mean_squared_error(y_test, y_pred_before, squared=False)
mae_before = mean_absolute_error(y_test, y_pred_before)
r2_before = r2_score(y_test, y_pred_before)

optimized_rf_model = joblib.load('best_rf_params_rs.joblib')

y_pred_optimized = optimized_rf_model.predict(X_test)

rmse_optimized = mean_squared_error(y_test, y_pred_optimized, squared=False)
mae_optimized = mean_absolute_error(y_test, y_pred_optimized)
r2_optimized = r2_score(y_test, y_pred_optimized)

results = pd.DataFrame({
    'Model': ['Random Forest Before Optimization', 'Random Forest After Optimization'],
    'RMSE': [rmse_before, rmse_optimized],
    'MAE': [mae_before, mae_optimized],
    'R2': [r2_before, r2_optimized]
})

results
# Out:
#                                Model       RMSE        MAE        R2
# 0  Random Forest Before Optimization  75.346008  48.502711  0.475702
# 1   Random Forest After Optimization  72.385100  47.124467  0.516100

# %% [markdown]
# ## 3.3 optimal GB model

# %% [markdown]
# ### 3.3.1 FInd optimal GP by using random search (run might take long time)

# %%
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

gb_model = GradientBoostingRegressor(random_state=42)

param_distributions = {
    'n_estimators': randint(100, 500),
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 5)
}

random_search = RandomizedSearchCV(estimator=gb_model, param_distributions=param_distributions, n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=42, verbose=1)
random_search.fit(X_train, y_train)

best_gb_model = random_search.best_estimator_
y_pred_gb = best_gb_model.predict(X_test)
rmse_gb = mean_squared_error(y_test, y_pred_gb, squared=False)
mae_gb = mean_absolute_error(y_test, y_pred_gb)
r2_gb = r2_score(y_test, y_pred_gb)

print("Best parameters:", random_search.best_params_)
print("RMSE:", rmse_gb)
print("MAE:", mae_gb)
print("R-squared:", r2_gb)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best parameters: {'learning_rate': 0.05, 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 343}
# RMSE: 70.69878304403152
# MAE: 46.63908116712053
# R-squared: 0.5383835449377785

# %%
#get the trained model into file for further prediction
best_params_grid_rs = random_search.best_estimator_
print("Best parameters:", best_params_grid_rs)

joblib.dump(best_params_grid_rs , 'best_gb_params_rs.joblib')
# Out:
# Best parameters: GradientBoostingRegressor(learning_rate=0.05, max_depth=5, min_samples_leaf=4,
#                           min_samples_split=8, n_estimators=343,
#                           random_state=42)
# ['best_gb_params_rs.joblib']

# %% [markdown]
# ### 3.3.2 upload the optimal GB model we have trained above to predict

# %%
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

gb_model_before = GradientBoostingRegressor(random_state=42)

gb_model_before.fit(X_train, y_train)

y_pred_before = gb_model_before.predict(X_test)

rmse_before = mean_squared_error(y_test, y_pred_before, squared=False)
mae_before = mean_absolute_error(y_test, y_pred_before)
r2_before = r2_score(y_test, y_pred_before)

optimized_gb_model = joblib.load('best_gb_params_rs.joblib')

y_pred_optimized = optimized_gb_model.predict(X_test)

rmse_optimized = mean_squared_error(y_test, y_pred_optimized, squared=False)
mae_optimized = mean_absolute_error(y_test, y_pred_optimized)
r2_optimized = r2_score(y_test, y_pred_optimized)

results = pd.DataFrame({
    'Model': ['Gradient Boosting Before Optimization', 'Gradient Boosting After Optimization'],
    'RMSE': [rmse_before, rmse_optimized],
    'MAE': [mae_before, mae_optimized],
    'R2': [r2_before, r2_optimized]
})

results
# Out:
#                                    Model       RMSE        MAE        R2
# 0  Gradient Boosting Before Optimization  72.049727  47.891976  0.520573
# 1   Gradient Boosting After Optimization  70.698783  46.639081  0.538384

# %% [markdown]
# # 4 Model selection and futher improve

# %% [markdown]
# ## 4.1 Stacking model with optimal RF and optimal gb

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
import joblib

# %%
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

optimized_rf_model = joblib.load('best_rf_params_rs.joblib')
optimized_gb_model = joblib.load('best_gb_params_rs.joblib')

base_models = [
    ('optimized_rf', optimized_rf_model),
    ('optimized_gb', optimized_gb_model)
]

meta_model = Ridge()

stacked_model = StackingRegressor(estimators=base_models, final_estimator=meta_model, cv=5)

stacked_model.fit(X_train, y_train)

y_pred_stack = stacked_model.predict(X_test)

rmse_stack = mean_squared_error(y_test, y_pred_stack, squared=False)
mae_stack = mean_absolute_error(y_test, y_pred_stack)
r2_stack = r2_score(y_test, y_pred_stack)

print("Stacking Model Evaluation Metrics:")
print("RMSE:", rmse_stack)
print("MAE:", mae_stack)
print("R-squared:", r2_stack)
# Out:
# Stacking Model Evaluation Metrics:
# RMSE: 70.54264031111698
# MAE: 46.41122097884881
# R-squared: 0.540420311549049

# %% [markdown]
# ## 4.2 improve the stacking model by using bagging (might run for a long time)

# %%
from sklearn.ensemble import BaggingRegressor

# %%
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

bagging_stacked_model = BaggingRegressor(estimator=stacked_model, n_estimators=10, random_state=42)

bagging_stacked_model.fit(X_train, y_train)

y_pred_bag_stack = bagging_stacked_model.predict(X_test)

rmse_bag_stack = mean_squared_error(y_test, y_pred_bag_stack, squared=False)
mae_bag_stack = mean_absolute_error(y_test, y_pred_bag_stack)
r2_bag_stack = r2_score(y_test, y_pred_bag_stack)

print("Bagging Stacked Model Evaluation Metrics:")
print("RMSE:", rmse_bag_stack)
print("MAE:", mae_bag_stack)
print("R-squared:", r2_bag_stack)
# Out:
# Bagging Stacked Model Evaluation Metrics:
# RMSE: 70.50760018163959
# MAE: 46.53386755140689
# R-squared: 0.5408767654660864

# %%
import joblib

joblib.dump(bagging_stacked_model, 'bagging_stacked_model.joblib')
# Out:
# ['bagging_stacked_model.joblib']

# %% [markdown]
# ## 4.3 using the model from above to predict by importing model file.

# %%
X = df_encoded.drop('price', axis=1)  
y = df_encoded['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

loaded_model = joblib.load('bagging_stacked_model.joblib')

y_pred = loaded_model.predict(X_test)

rmse = mean_squared_error(y_test, y_pred, squared=False)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Evaluation Metrics:")
print("RMSE:", rmse)
print("MAE:", mae)
print("R-squared:", r2)
# Out:
# Evaluation Metrics:
# RMSE: 70.50760018163959
# MAE: 46.53386755140689
# R-squared: 0.5408767654660864
